# %% [markdown]
# ### Team Member:
#
# Sajjani.P( USN:1RVU22BSC087)
#
# Sumedha.V (USN:1RVU22BSC101)

# %% [markdown]
# #**Soil** **Fertility** **Prediction**

# %% [markdown]
# ## **Data Preprocessing**

# %%
import pandas as pd
df=pd.read_csv("Soil_Fertility_iml.csv") # reading the csv file
df#displaying
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 875  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 876  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 877  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 878  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 879  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#     Soil_fertility
# 0      Not Fertile
# ...

# %%
df.isnull().sum() # finding null values
# Out:
# N                 0
# P                 0
# K                 0
# pH                0
# EC                0
# OC                0
# S                 0
# Zn                0
# Fe                0
# Cu                0
# Mn                0
# B                 0
# Soil_fertility    0
# dtype: int64

# %%
df.duplicated().sum() # finding the duplicates
# Out:
# 0

# %%
df.describe()
# Out:
#                N           P           K          pH          EC          OC  \
# count  880.00000  880.000000  880.000000  880.000000  880.000000  880.000000
# mean   246.73750   14.562159  499.978409    7.510500    0.543659    0.617989
# std     77.38886   21.967755  124.222838    0.464912    0.141597    0.842986
# min      6.00000    2.900000   11.000000    0.900000    0.100000    0.100000
# 25%    201.00000    6.800000  412.000000    7.350000    0.430000    0.380000
# 50%    257.00000    8.100000  475.000000    7.500000    0.545000    0.590000
# 75%    307.00000   10.550000  581.000000    7.630000    0.640000    0.780000
# max    383.00000  125.000000  887.000000   11.150000    0.950000   24.000000
#
#                 S          Zn          Fe          Cu          Mn           B
# count  880.000000  880.000000  880.000000  880.000000  880.000000  880.000000
# mean     7.545080    0.469273    4.140523    0.952443    8.666500    0.590159
# ...

# %%
df.shape
# Out:
# (880, 13)

# %% [markdown]
# ## **Encoding**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   N               880 non-null    int64
#  1   P               880 non-null    float64
#  2   K               880 non-null    int64
#  3   pH              880 non-null    float64
#  4   EC              880 non-null    float64
#  5   OC              880 non-null    float64
#  6   S               880 non-null    float64
#  7   Zn              880 non-null    float64
#  8   Fe              880 non-null    float64
#  9   Cu              880 non-null    float64
#  10  Mn              880 non-null    float64
#  11  B               880 non-null    float64
#  12  Soil_fertility  880 non-null    object
# dtypes: float64(10), int64(2), object(1)
# memory usage: 89.5+ KB

# %% [markdown]
# ### Label Encoding (as the output represent the ordinal relationship)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Fit and transform the data
df['Soil_fertility'] = le.fit_transform(df['Soil_fertility'])
df
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 875  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 876  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 877  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 878  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 879  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#      Soil_fertility
# 0                 1
# ...

# %%
# Labels are the index values of the elements present in the below array

le.classes_
# Out:
# array(['Fertile', 'Not Fertile'], dtype=object)

# %%
X = df.iloc[::,:-1]
y = df.iloc[::,-1:]

# %% [markdown]
# ## **Detecting Outliers:**
#
# ### 1.Visualization (Box Plot):
#
# ### Check for outliers using boxplot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.boxplot(df)
plt.title('Soil_Fertile')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## **2. Using Z-Scores**
#
# ### Check for outliers using Z-scores method

# %%
from scipy import stats


# Specify columns to check for outliers
columns_to_check = ['N','K']
# Calculate Z-scores for each column
z_scores = stats.zscore(df[columns_to_check])

# Define a threshold for outlier detection (e.g., 3 standard deviations)
threshold = 3
outlier_indices = (z_scores > threshold).any(axis=1)
outliers_df = df[outlier_indices]

print("Rows with Outliers:\n")
outliers_df
# Out:
# Rows with Outliers:
#        N     P    K   pH    EC    OC     S    Zn    Fe    Cu     Mn     B  \
# 290  257   7.5  887  7.5  0.29  0.79  4.50  0.26  2.84  0.67   6.76  0.12
# 334  264   9.4  876  7.8  0.38  0.29  3.92  0.26  3.51  0.69  11.68  0.46
# 749  333  12.7  887  7.4  0.42  0.68  5.43  0.34  1.96  2.01  14.52  0.34
# 862  333  12.7  887  7.1  0.42  0.88  6.33  0.75  4.96  1.08  12.03  0.59
#
#      Soil_fertility
# 290               0
# 334               0
# 749               0
# 862               0

# %% [markdown]
# ##  **Handling outliers**

# %%
# Cap and floor values using quantiles
lower_limit = df[columns_to_check].quantile(0.05)
upper_limit = df[columns_to_check].quantile(0.95)

df_capped = df.copy()
df_capped[columns_to_check] = df_capped[columns_to_check].clip(lower_limit, upper_limit, axis=1)
df_capped
# Out:
#        N     P    K    pH    EC    OC      S    Zn    Fe    Cu     Mn     B  \
# 0    138   8.6  560  7.46  0.62  0.70   5.90  0.24  0.31  0.77   8.71  0.11
# 1    213   7.5  338  7.62  0.75  1.06  25.40  0.30  0.86  1.54   2.89  2.29
# 2    163   9.6  718  7.59  0.51  1.11  14.30  0.30  0.86  1.57   2.70  2.03
# 3    157   6.8  475  7.64  0.58  0.94  26.00  0.34  0.54  1.53   2.65  1.82
# 4    270   9.9  444  7.63  0.40  0.86  11.80  0.25  0.76  1.69   2.43  2.26
# ..   ...   ...  ...   ...   ...   ...    ...   ...   ...   ...    ...   ...
# 875  351  10.7  623  7.96  0.51  0.29   7.24  0.36  4.69  0.69  11.03  0.69
# 876  264   9.0  486  7.24  0.47  0.10   3.92  0.35  8.26  0.45   7.98  0.40
# 877  276   9.2  370  7.62  0.62  0.49   6.64  0.42  3.57  0.63   6.48  0.32
# 878  320  13.8  391  7.38  0.65  1.07   5.43  0.58  4.58  1.02  13.25  0.53
# 879  264  10.3  475  7.49  0.74  0.88  10.56  0.45  7.36  1.87  10.63  0.63
#
#      Soil_fertility
# 0                 1
# ...

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(df_capped)
plt.title('Soil_Fertility')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## **Scaling**
# ### Min Max Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()
minmax_data = minmax.fit_transform(X)
minmax_df = pd.DataFrame(minmax_data, columns=X.columns)
minmax_df
# Out:
#             N         P         K        pH        EC        OC         S  \
# 0    0.350133  0.046683  0.626712  0.640000  0.611765  0.025105  0.173254
# 1    0.549072  0.037674  0.373288  0.655610  0.764706  0.040167  0.815547
# 2    0.416446  0.054873  0.807078  0.652683  0.482353  0.042259  0.449934
# 3    0.400531  0.031941  0.529680  0.657561  0.564706  0.035146  0.835310
# 4    0.700265  0.057330  0.494292  0.656585  0.352941  0.031799  0.367589
# ..        ...       ...       ...       ...       ...       ...       ...
# 875  0.915119  0.063882  0.698630  0.688780  0.482353  0.007950  0.217391
# 876  0.684350  0.049959  0.542237  0.618537  0.435294  0.000000  0.108037
# 877  0.716180  0.051597  0.409817  0.655610  0.611765  0.016318  0.197628
# 878  0.832891  0.089271  0.433790  0.632195  0.647059  0.040586  0.157773
# 879  0.684350  0.060606  0.529680  0.642927  0.752941  0.032636  0.326746
#
#            Zn        Fe        Cu        Mn         B
# ...

# %% [markdown]
# ## Importing the models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Defininf X and y

# %%
X = minmax_df  # Features
y = df['Soil_fertility']

# %% [markdown]
# ## Spliting the data

# %%
from sklearn.model_selection import train_test_split,cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %% [markdown]
# # **KNN**

# %%
classifier = KNeighborsClassifier(n_neighbors = 20)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
cr = classification_report(y_test, y_pred)
print("\nClassification Report:",)
print (cr)
acc = accuracy_score(y_test,y_pred)
print("\nAccuracy:",acc)
# Out:
# Confusion Matrix:
# [[132  11]
#  [ 18 103]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       143
#            1       0.90      0.85      0.88       121
#
#     accuracy                           0.89       264
#    macro avg       0.89      0.89      0.89       264
# weighted avg       0.89      0.89      0.89       264
#
#
# Accuracy: 0.8901515151515151

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(max_depth = 40, min_samples_leaf=25) # criterion = 'entropy'
# The maximum depth of the tree.
# If None, then nodes are expanded until all leaves are pure or until all leaves contain less than min_samples_split samples.
# The minimum number of samples required to be at a leaf node.
# criterion = {“gini”, “entropy”, “log_loss”}, default=”gini”
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=40, min_samples_leaf=25)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
cr = classification_report(y_test, y_pred)
print("\nClassification Report:",)
print (cr)
acc = accuracy_score(y_test,y_pred)
print("\nAccuracy:",acc)
# Out:
# Confusion Matrix:
# [[133  10]
#  [  9 112]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       143
#            1       0.92      0.93      0.92       121
#
#     accuracy                           0.93       264
#    macro avg       0.93      0.93      0.93       264
# weighted avg       0.93      0.93      0.93       264
#
#
# Accuracy: 0.928030303030303

# %%
from sklearn import tree
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
tree.plot_tree(dt,filled=True)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation to get accuracy scores for each fold
cv_scores = cross_val_score(dt, X, y, cv=5)

# Print accuracy scores for each fold
print("Cross-validation scores:", cv_scores)

# Calculate and print the mean accuracy score
mean_accuracy = np.mean(cv_scores)
print("Mean CV accuracy:", mean_accuracy)
# Out:
# Cross-validation scores: [0.91477273 0.96022727 0.94318182 0.96590909 0.77840909]
# Mean CV accuracy: 0.9125

# %% [markdown]
# ## Performing Grid Search cross-validation

# %%
from sklearn.model_selection import GridSearchCV

# Create the parameter grid based on the results of random search
params = {
    'max_depth': [2, 3, 5, 15, 25],
    'min_samples_leaf': [5, 10, 25, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt,
                           param_grid=params,
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# CPU times: user 254 ms, sys: 48.1 ms, total: 302 ms
# Wall time: 5.6 s
# GridSearchCV(cv=4,
#              estimator=DecisionTreeClassifier(max_depth=40,
#                                               min_samples_leaf=25),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 15, 25],
#                          'min_samples_leaf': [5, 10, 25, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.010554      0.004899         0.006040        0.002964
# 1       0.006411      0.002683         0.007633        0.003251
# 2       0.010852      0.000923         0.003262        0.000168
# 3       0.008703      0.003033         0.006778        0.003662
# 4       0.008201      0.003054         0.005922        0.003304
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               2                      5
# 1            gini               2                     10
# 2            gini               2                     25
# 3            gini               2                     50
# 4            gini               2                    100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.902597
# 1  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.902597
# ...

# %%
score_df.nlargest(5,"mean_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 30       0.005409      0.000128         0.003059        0.000111
# 5        0.008862      0.004033         0.005966        0.003937
# 0        0.010554      0.004899         0.006040        0.002964
# 1        0.006411      0.002683         0.007633        0.003251
# 2        0.010852      0.000923         0.003262        0.000168
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 30         entropy               3                      5
# 5             gini               3                      5
# 0             gini               2                      5
# 1             gini               2                     10
# 2             gini               2                     25
#
#                                                params  split0_test_score  \
# 30  {'criterion': 'entropy', 'max_depth': 3, 'min_...           0.935065
# 5   {'criterion': 'gini', 'max_depth': 3, 'min_sam...           0.935065
# ...

# %%
dt_best = grid_search.best_estimator_

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy :", accuracy_score(y_train, dt_classifier.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, dt_classifier.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %%
evaluate_model(dt_best)
# Out:
# Train Accuracy : 0.952922077922078
# Train Confusion Matrix:
# [[317  19]
#  [ 10 270]]
# --------------------------------------------------
# Test Accuracy : 0.946969696969697
# Test Confusion Matrix:
# [[133  10]
#  [  4 117]]

# %% [markdown]
# # **Random Forest**

# %%
#Train a machine learning model

from sklearn.ensemble import RandomForestClassifier
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', RandomForestClassifier(random_state=42))
])

pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
# Modelling
# Random forest Classifier
clf = RandomForestClassifier(n_estimators = 40) # Random Forest with 20 trees

clf.fit(X, y) # It can only handle numerical attributes!
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
# Model Evaluation
from sklearn.metrics import classification_report

# Make prediction on the testing data
y_pred = pipeline.predict(X_test)

# Classification Report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       140
#            1       0.95      0.93      0.94       124
#
#     accuracy                           0.94       264
#    macro avg       0.94      0.94      0.94       264
# weighted avg       0.94      0.94      0.94       264

# %% [markdown]
# # **Logistic Regression**

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# 0.9166666666666666

# %% [markdown]
# ## Demonstration of Ensemble Learning Technique : **Bagging Classifier**

# %% [markdown]
# ### Decision Tree with Bagging Technique

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier

# Define a pipeline for the DecisionTreeClassifier
pipeline1 = Pipeline([
    ('scaler', StandardScaler()),
    ('classifier', DecisionTreeClassifier(random_state=42))
])

# Fit the pipeline to the training data
pipeline1.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('classifier', DecisionTreeClassifier(random_state=42))])

# %%
# Bagging Classifier
#improve the model performance by increasing n_estimators 50
from sklearn.ensemble import BaggingClassifier

# Create a bagging classifier with the decision tree pipeline1
bagging_classifier = BaggingClassifier(base_estimator=pipeline1, n_estimators=40, random_state=32)

# Train the bagging classifier on the training data
bagging_classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                                  ('classifier',
#                                                   DecisionTreeClassifier(random_state=42))]),
#                   n_estimators=40, random_state=32)

# %%
# Evaluate the classifier using cross-validation
import numpy as np
cv_scores = cross_val_score(bagging_classifier, X, y, cv=4)

print(f"Cross-validation scores: {cv_scores}")
print(f"Mean CV accuracy: {np.mean(cv_scores):.2f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Cross-validation scores: [0.91818182 0.95909091 0.92272727 0.83181818]
# Mean CV accuracy: 0.91

# %% [markdown]
# # **Report :**

# %% [markdown]
# ###**Soil Fertility Prediction**
#
# ###**Dataset Overview:**
#
# The soil fertility dataset comprises 881 samples and 13 features, encompassing various soil properties like nutrient content (N, P, K), soil acidity (pH), electrical conductivity (EC), and presence of essential elements like sulphur (S), zinc (Zn), iron (Fe), copper (Cu), manganese (Mn), and boron (B). Soil samples are categorized into two fertility classes: "Not Fertile" (1) and "Fertile" (0).
#
# ###**Steps:**
#
# ###**Data Preprocessing:**
#
# **Data Check:** The dataset was checked for null and duplicate values, ensuring data integrity.
#
# **Encoding:** Since the target variable has two classes (Fertile and Not Fertile), label encoding was applied, assigning numerical values to each class that is Fertile as "0" and Not fertile as "1".
#
# **Scaling:** Min-max scaling was performed on numeric features to bring them within a fixed range (0-1), aiding model convergence and performance.
#
# **Outlier Detection and Removal:** Boxplot analysis revealed outliers in the nitrogen (N) and phosphorus (P) features.
# Outliers were removed to improve the robustness of the dataset.
#
# ###**Model Selection:**
#
# The models considered include K-Nearest Neighbors (KNN), Decision Trees (DT) with and without bagging, Random Forest, Logistic Regression, and Bagging Classifier.
#
# ###**Model Training and Evaluation:**
#
#
#
# *   The dataset was split into training and testing sets using a 70-30 ratio.
# *   Model performance metrics such as confusion matrix, classification report, and accuracy score were computed for each model.
#
# *  Grid search was employed to optimize hyperparameters for Decision Trees, ensuring enhanced model performance.
#
#
#
#
#
#
#
#
# ###**Results:**
#
# K-Nearest Neighbors (KNN) achieved an accuracy of 89%.
# Decision Tree (DT) achieved an accuracy of 92%.
# Random Forest attained an accuracy of 94%.
# Logistic Regression reached an accuracy of 91%.
# Bagging was performed to assess potential overfitting for the Decision Tree model, and the accuracy for both the original and bagged models remained almost the same.
# Considering the overall performance, Random Forest exhibited the highest accuracy among the tested algorithms.
#
# ###**Conclusion:**
#
# Random Forest emerged as the top performer with an accuracy of 94%. While Decision Tree, Logistic Regression, and KNN also demonstrated respectable accuracies, Random Forest's robust performance suggests its suitability for soil fertility prediction tasks. Bagging, although applied specifically to the Decision Tree model in this study, offers a valuable technique for assessing overfitting and enhancing generalization across unseen data.
